# %%
import torch
#print(torch.__version__)
# Out:
# 2.1.0+cu118

# %%
# !pip install git+https://github.com/suno-ai/bark.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 19.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 69.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.6 MB/s eta 0:00:00
# ...

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from IPython.display import Audio

preload_models()
# Out:
# text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# coarse_2.pt:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# fine_2.pt:   0%|          | 0.00/3.74G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /root/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:01<00:00, 69.3MB/s]

# %%
text = "Hello  good morning, I hope you doin well [laughs]"

audio_arr = generate_audio(text)
Audio(audio_arr, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 12/12 [00:09<00:00,  1.32it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = "Hello  good morning, I hope you doin well [laughs]"

audio_arr = generate_audio(text, history_prompt="v2/en_speaker_4")
Audio(audio_arr, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 18/18 [00:16<00:00,  1.12it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = """MAN: Hello  good morning, I hope you doin well
         WOMAN: hey good morning, how are you?
 """

audio_arr = generate_audio(text)
Audio(audio_arr, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 21/21 [00:17<00:00,  1.18it/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#for saving audio file
import scipy
scipy.io.wavfile.write("output.wav",rate=SAMPLE_RATE, data=audio_arr)
